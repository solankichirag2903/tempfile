# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %%
# Load the Netflix dataset
df = pd.read_csv('netflix_titles.csv')  # Replace with the actual dataset file name and path

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
children_movies = df[(df['type'] == 'Movie') & (df['listed_in'].str.contains('Children'))]
children_movies_count = len(children_movies)

# %%
children_movies
# Out:
#      show_id   type                                         title  \
# 6         s7  Movie              My Little Pony: A New Generation
# 13       s14  Movie              Confessions of an Invisible Girl
# 23       s24  Movie  Go! Go! Cory Carson: Chrissy Takes the Wheel
# 64       s65  Movie                                    Nightbooks
# 71       s72  Movie                   A StoryBots Space Adventure
# ...      ...    ...                                           ...
# 8781   s8782  Movie                       Yo-Kai Watch: The Movie
# 8784   s8785  Movie                          Yoko and His Friends
# 8786   s8787  Movie                                  You Can Tutu
# 8793   s8794  Movie                          Yours, Mine and Ours
# 8805   s8806  Movie                                          Zoom
#
#                            director  \
# 6     Robert Cullen, José Luis Ucha
# 13                    Bruno Garotti
# 23          Alex Woo, Stanley Moore
# ...

# %%
len(children_movies)
# Out:
# 641

# %%
children_movies_count
# Out:
# 641

# %%
children_movies
# Out:
#      show_id   type                                         title  \
# 6         s7  Movie              My Little Pony: A New Generation
# 13       s14  Movie              Confessions of an Invisible Girl
# 23       s24  Movie  Go! Go! Cory Carson: Chrissy Takes the Wheel
# 64       s65  Movie                                    Nightbooks
# 71       s72  Movie                   A StoryBots Space Adventure
# ...      ...    ...                                           ...
# 8781   s8782  Movie                       Yo-Kai Watch: The Movie
# 8784   s8785  Movie                          Yoko and His Friends
# 8786   s8787  Movie                                  You Can Tutu
# 8793   s8794  Movie                          Yours, Mine and Ours
# 8805   s8806  Movie                                          Zoom
#
#                            director  \
# 6     Robert Cullen, José Luis Ucha
# 13                    Bruno Garotti
# 23          Alex Woo, Stanley Moore
# ...

# %%
#2. Total Number of Stand-Up Comedies
standup_comedies = df[df['listed_in'].str.contains('Stand-Up Comedy')]
standup_comedies_count = len(standup_comedies)

# %%
standup_comedies_count
# Out:
# 399

# %%
standup_comedies
# Out:
#      show_id     type                                              title  \
# 278     s279    Movie                        Lokillo: Nothing's the Same
# 359     s360    Movie                       The Original Kings of Comedy
# 388     s389  TV Show            Plastic Cup Boyz: Laughing My Mask Off!
# 400     s401  TV Show  Revelations: The Masters of the Universe: Reve...
# 475     s476    Movie                                       The Stand-Up
# ...      ...      ...                                                ...
# 7812   s7813  TV Show                                   Queens of Comedy
# 7813   s7814  TV Show                                   Queens vs. Kings
# 7908   s7909  TV Show                       Russell Peters vs. the World
# 7909   s7910    Movie                          Russell Peters: Notorious
# 8437   s8438  TV Show                             The Netflix Afterparty
#
#                              director  \
# 278                    Julián Gaviria
# ...

# %%
most_watched_shows = df['title'].value_counts().head(5)

# %%
most_watched_shows
# Out:
# title
# Dick Johnson Is Dead                1
# Ip Man 2                            1
# Hannibal Buress: Comedy Camisado    1
# Turbo FAST                          1
# Masha's Tales                       1
# Name: count, dtype: int64

# %%
# Create Visualizations
plt.figure(figsize=(10, 6))
plt.bar(['Children Movies', 'Stand-Up Comedies'], [children_movies_count, standup_comedies_count])
plt.title('Total Number of Movies Watched by Children and Stand-Up Comedies')
plt.xlabel('Category')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(10, 6))
most_watched_shows.plot(kind='bar')
plt.title('Most Watched Shows')
plt.xlabel('Show Title')
plt.ylabel('Watch Count')
# Out:
# Text(0, 0.5, 'Watch Count')

# %%
# Assuming "highest_rated_show" is a DataFrame with a single row
plt.figure(figsize=(10, 6))
plt.bar(highest_rated_show['title'], highest_rated_show['rating'])
plt.title('Highest Rated Show')
plt.xlabel('Show Title')
plt.ylabel('rating')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 # Assuming "highest_rated_show" is a DataFrame with a single row
#       2 plt.figure(figsize=(10, 6))
# ----> 3 plt.bar(highest_rated_show['title'], highest_rated_show['rating'])
#       4 plt.title('Highest Rated Show')
#       5 plt.xlabel('Show Title')
#
# NameError: name 'highest_rated_show' is not defined

# %%
ratings =Counter(df['rating'])
ratings = dict(ratings)
ratings

# %%
ratings = Counter(df['rating'])
ratings =dict(ratings)
ratings
# Out:
# {'PG-13': 490,
#  'TV-MA': 3207,
#  'PG': 287,
#  'TV-14': 2160,
#  'TV-PG': 863,
#  'TV-Y': 307,
#  'TV-Y7': 334,
#  'R': 799,
#  'TV-G': 220,
#  'G': 41,
#  'NC-17': 3,
#  '74 min': 1,
#  '84 min': 1,
#  '66 min': 1,
#  'NR': 80,
#  nan: 4,
#  'TV-Y7-FV': 6,
#  'UR': 3}

# %%
plt.figure(figsize=(16,9))
plt.plot(list(ratings.keys()),
         list(ratings.values()),color='blue',marker='o')
plt.xlabel('Ratings')
plt.ylabel("Total Count")
plt.grid()

# %%
plt.figure(figsize=(16,9))
plt.plot(list(ratings.keys()),list(ratings.values()),color='blue',marker='o')

plt.xlabel('RAINGS')
plt.ylabel("TOtal count")
plt.grid()

# %%
plt.subplot(2,2,1)
plt.title('children_movies vs Stan-up ')
plt.bar(['children_movies','Stand-up Comedy'],[standup_comedies_count,standup_comedies])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 3
#       1 plt.subplot(2,2,1)
#       2 plt.title('children_movies vs Stan-up ')
# ----> 3 plt.bar(['children_movies','Stand-up Comedy'],[standup_comedies_count,standup_comedies])
#
# File ~\OneDrive\Documents\anaconda\Lib\site-packages\matplotlib\pyplot.py:2439, in bar(x, height, width, bottom, align, data, **kwargs)
#    2435 @_copy_docstring_and_deprecators(Axes.bar)
#    2436 def bar(
#    2437         x, height, width=0.8, bottom=None, *, align='center',
#    2438         data=None, **kwargs):
# -> 2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
#    2441         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %%
#plot3
plt.subplot(2,1,2)
plt.title("Ratings")
plt.plot(list(ratings.keys()),
        list(ratings.values()),color='red',marker='o')
plt.xlabel("Ratings")
plt.ylabel("Total Count")
plt.grid()
