# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#           ID  LIMIT_BAL     SEX        EDUCATION MARITAL_STATUS  AGE  \
# 0      12194   220000.0  FEMALE  graduate school        MARRIED   54
# 1       7068    90000.0  FEMALE  graduate school         SINGLE   30
# 2       1446    80000.0  FEMALE       university         SINGLE   25
# 3        318   260000.0  FEMALE      high school        MARRIED   53
# 4      13732    30000.0  FEMALE       university         SINGLE   23
# ...      ...        ...     ...              ...            ...  ...
# 20995  16350   210000.0  FEMALE  graduate school         SINGLE   37
# 20996   5187   230000.0    MALE  graduate school         SINGLE   39
# 20997   4825   200000.0    MALE  graduate school        MARRIED   31
# 20998  29044    50000.0  FEMALE       university        MARRIED   50
# 20999  28154   210000.0  FEMALE  graduate school        MARRIED   34
#
#        INSTALLMENT_1  INSTALLMENT_2  INSTALLMENT_3  INSTALLMENT_AMT_1  \
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARITAL_STATUS                0
# AGE                           0
# INSTALLMENT_1                 0
# INSTALLMENT_2                 0
# INSTALLMENT_3                 0
# INSTALLMENT_AMT_1             0
# INSTALLMENT_AMT_2             0
# INSTALLMENT_AMT_3             0
# INSTALLMENT_PAID_1            0
# INSTALLMENT_PAID_2            0
# INSTALLMENT_PAID_3            0
# DEFAULT.PAYMENT.NEXT.MONTH    0
# dtype: int64

# %%
df['']
