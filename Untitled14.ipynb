# %%
import pandas as  pd

# %%
df = pd.read_csv("Ttrain.csv")

# %%
df
# Out:
#       Unnamed: 0  LABEL  FLUX.1  FLUX.2  FLUX.3  FLUX.4  FLUX.5  FLUX.6  \
# 0              0      1  141.16   96.00  108.94   73.85   80.94   51.76
# 1              1      1   -8.02  -12.89   -6.35   -4.66   -1.37   -1.16
# 2              2      1   -4.17   -1.58   -6.45   -6.82   -7.09    3.35
# 3              3      1    3.91    2.09    2.75    3.49    0.46    0.47
# 4              4      1 -101.50  -28.25  -14.90  -41.78   44.35   38.16
# ...          ...    ...     ...     ...     ...     ...     ...     ...
# 5082        5082      1   23.69   25.07   12.32   18.14   18.09   10.15
# 5083        5083      1  357.18  351.72  354.94  350.62  314.03  359.87
# 5084        5084      1  -10.47   -9.94   -5.95   -7.06    0.48  -10.15
# 5085        5085      1 -124.66 -120.41   -5.93  264.81  618.46  990.70
# 5086        5086      1  145.17  147.56  102.06  190.87  234.20  199.08
#
#        FLUX.7   FLUX.8  ...  FLUX.3188  FLUX.3189  FLUX.3190  FLUX.3191  \
# ...
